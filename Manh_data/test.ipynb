# %%
import pandas as pd

# %%
df = pd.read_csv('Razer DeathAdder Essential Gaming Mouse.csv')

# %%
df
# Out:
#                  user star                                             sumary  \
# 0      Jake Fleischer    5                                      Amazing Stuff
# 1       Ashton Cooper    5                     "Essential" is the right word!
# 2    Elhan Martinovic    5                                         Great buy!
# 3        Alvin Jacobs    5  The Perfect Gaming Mouse with Exceptional Perf...
# 4         Mike Eckman    5                          Great Mouse for Basic Use
# ..                ...  ...                                                ...
# 499      Anita Carter    1                                              yikes
# 500           Matt Z.    1                             Double Clicking Menace
# 501             Cutty    1                     Mouse scroll wheel is garbage.
# 502    AmazonCustomer    1  Scroll wheel defect - Buying from Amazon voids...
# 503      VerifiedUser    1                                Scrolling bar issue
#
# ...

# %%
df.iloc[10]
# Out:
# user                                          Charles Christopher
# star                                                            5
# sumary                                                Comfortable
# country&time       Reviewed in the United States on March 5, 2024
# kind item                   Color: Classic BlackVerified Purchase
# image                                                           0
# comment         Feels good in the hand and highly responsive. ...
# Name: 10, dtype: object
